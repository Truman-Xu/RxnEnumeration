# %%
from ridgeplot_1 import smiFileToDF, ridgeplot_simple, ridgeplot_bo

# %%
df = smiFileToDF('quinine-aniline.smi')
df
# Out:
#       MolWt   LogP  HBA  HBD    PSA  RotB      FPS3  FC   QED  Arom  \
# 0   415.537  4.397    5    2  57.62     6  0.346154   0  0.46     3
# 1   415.537  4.408    5    2  57.62     6  0.346154   0  0.58     3
# 2   415.537  4.264    5    2  57.62     6  0.346154   0  0.59     3
# 3   415.537  4.613    5    2  57.62     6  0.346154   0  0.62     3
# 4   415.537  4.613    5    2  57.62     7  0.346154   0  0.44     3
# ..      ...    ...  ...  ...    ...   ...       ...  ..   ...   ...
# 75  400.522  4.840    4    1  45.59     5  0.346154   0  0.62     3
# 76  400.522  4.840    4    1  45.59     5  0.346154   0  0.62     3
# 77  400.522  4.840    4    1  45.59     5  0.346154   0  0.62     3
# 78  400.522  4.840    4    1  45.59     5  0.346154   0  0.62     3
# 79  400.522  4.840    4    1  45.59     5  0.346154   0  0.62     3
#
#                                               SMILES
# 0   C=CC1CN2CCC1CC2C(O)(Nc1ccccc1)c1ccnc2ccc(OC)cc12
# ...

# %%
ridgeplot_simple(df)
# Out:
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# Plotting Finished.

# %%
ridgeplot_bo(df)
# Out:
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/ziqiaoxu/.conda/envs/tmap/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Plotting Finished.
